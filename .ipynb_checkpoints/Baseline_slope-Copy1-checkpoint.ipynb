# %%
import numpy as np
import pandas as pd
import glob
from numba import guvectorize
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import os
from datetime import datetime, timezone
import re
import json
import awkward as ak
import pygama 


from dbetto import Props
from legendmeta import LegendMetadata
from lgdo import lh5
import lgdo
from dspeed.vis.waveform_browser import WaveformBrowser
from pygama.pargen.dsp_optimize import run_one_dsp
import lgdo.types as lgdo_types
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
import matplotlib.patches as mpatches
from collections import defaultdict
from pathlib import Path

import itertools
from tqdm import tqdm
import time

# %% [markdown]
# # Path to data

# %%
data_path = "/global/cfs/cdirs/m2676/data/lngs/l200/public/prodenv/prod-blind/ref/latest"
config = Props.read_from(os.path.join(data_path, "config.json"), subst_pathvar=True)["setups"]["l200"]["paths"]

# %%
lmeta  = LegendMetadata(config["metadata"])

# %%
chmap = ak.Array(lmeta.channelmap(lmeta.dataprod.runinfo.p03.r000.phy.start_key).group("system").geds.values())

# %%
detector = "V02160A"
chn = chmap.daq.rawid[chmap.name == detector][0]

# %% [markdown]
# # Masck for detector type

# %%
names = chmap["name"]
mask_icpc = (names[:, 0] == "V")
mask_bege = (names[:, 0] == "B")
mask_coax = (names[:, 0] == "C")
mask_ppc  = (names[:, 0] == "P")

# %% [markdown]
# # Functions

# %%
def gaussian(x, A, mu, sigma, C):
    return A * np.exp(-0.5 * ((x - mu) / sigma)**2) + C

# %%
def fit_baseline(waves, calcs, i_start=0, i_end=500, order=1):
    """ Polynomial fit [order], vectorized version of baseline calcsulator
    TODO: arbitrary orders?
    """
    wf_block = waves["waveform"]

    # run polyfit
    x = np.arange(i_start, i_end)
    wfs = wf_block[:, i_start:i_end].T
    pol = np.polynomial.polynomial.polyfit(x, wfs, order).T

    # add the result as new columns
    calcs["bl_int"] = pol[:,0]
    calcs["bl_slope"] = pol[:,1]
    return calcs

# %%
def fit_baseline_per_event(values, i_start=0, i_end=len(wfs["values"][0]), order=1):

    
    x = np.arange(i_start, i_end)
    y = values[:, i_start:i_end]

    coeffs = np.array([
        np.polynomial.polynomial.polyfit(x, y[i], order).T
        for i in range(y.shape[0])
    ])

    return ak.Array([
        {
            "event": i,
            "bl_int": coeffs[i, 0],
            "bl_slope": coeffs[i, 1] if order > 0 else 0.0
        }
        for i in range(len(coeffs))
    ])

# %% [markdown]
# # Take data
#
# For the baseline slope cuts you need:
# - presummed waveforms
# - fft data OR (in oldest periods) FT in phy data

# %%
config['tier_raw']
fft_files = sorted(glob.glob(f"{config['tier_raw']}/fft/p08/r004/l200-p08-r004-fft-20231030T184107Z-tier_raw.lh5"))

# %%
for f in fft_files:
    print("\nFILE:", f)
    lh5.show(f)
# Out:
# FILE: /global/cfs/cdirs/m2676/data/lngs/l200/public/prodenv/prod-blind/ref/latest/../v0.1.0/generated/tier/raw/fft/p08/r004/l200-p08-r004-fft-20231030T184107Z-tier_raw.lh5
# /
# ├── FCConfig · table{packet_id,packet_len,readout_id,fcid,telid,nadcs,ntriggers,nsamples,adcbits,sumlength,blprecision,mastercards,triggercards,adccards,gps,ch_board_id,ch_inputnum,board_rev,board_uid}
# │   ├── adcbits · array<1>{real}
# │   ├── adccards · array<1>{real}
# │   ├── blprecision · array<1>{real}
# │   ├── board_rev · array<1>{array<1>{real}}
# │   │   ├── cumulative_length · array<1>{real}
# │   │   └── flattened_data · array<1>{real}
# │   ├── board_uid · array<1>{array<1>{real}}
# │   │   ├── cumulative_length · array<1>{real}
# │   │   └── flattened_data · array<1>{real}
# │   ├── ch_board_id · array<1>{array<1>{real}}
# │   │   ├── cumulative_length · array<1>{real}
# │   │   └── flattened_data · array<1>{real}
# │   ├── ch_inputnum · array<1>{array<1>{real}}
# │   │   ├── cumulative_length · array<1>{real}
# │   │   └── flattened_data · array<1>{real}
# │   ├── fcid · array<1>{real}
# │   ├── gps · array<1>{real}
# │   ├── mastercards · array<1>{real}
# │   ├── nadcs · array<1>{real}
# │   ├── nsamples · array<1>{real}
# │   ├── ntriggers · array<1>{real}
# │   ├── packet_id · array<1>{real}
# │   ├── packet_len · array<1>{real}
# │   ├── readout_id · array<1>{real}
# │   ├── sumlength · array<1>{real}
# │   ├── telid · array<1>{real}
# │   └── triggercards · array<1>{real}
# ├── OrcaHeader · string
# ├── ch1027200 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_windowed,presum_rate,waveform_presummed,t_sat_lo,t_sat_hi}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── presum_rate · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── t_sat_hi · array<1>{real}
# │       ├── t_sat_lo · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       ├── waveform_presummed · table{t0,dt,values}
# │       │   ├── dt · array<1>{real}
# │       │   ├── t0 · array<1>{real}
# │       │   └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │       │       ├── decoded_size · real
# │       │       └── encoded_data · array<1>{array<1>{real}}
# │       │           ├── cumulative_length · array<1>{real}
# │       │           └── flattened_data · array<1>{real}
# │       └── waveform_windowed · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1027201 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_windowed,presum_rate,waveform_presummed,t_sat_lo,t_sat_hi}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── presum_rate · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── t_sat_hi · array<1>{real}
# │       ├── t_sat_lo · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       ├── waveform_presummed · table{t0,dt,values}
# │       │   ├── dt · array<1>{real}
# │       │   ├── t0 · array<1>{real}
# │       │   └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │       │       ├── decoded_size · real
# │       │       └── encoded_data · array<1>{array<1>{real}}
# │       │           ├── cumulative_length · array<1>{real}
# │       │           └── flattened_data · array<1>{real}
# │       └── waveform_windowed · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1027202 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_windowed,presum_rate,waveform_presummed,t_sat_lo,t_sat_hi}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── presum_rate · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── t_sat_hi · array<1>{real}
# │       ├── t_sat_lo · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       ├── waveform_presummed · table{t0,dt,values}
# │       │   ├── dt · array<1>{real}
# │       │   ├── t0 · array<1>{real}
# │       │   └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │       │       ├── decoded_size · real
# │       │       └── encoded_data · array<1>{array<1>{real}}
# │       │           ├── cumulative_length · array<1>{real}
# │       │           └── flattened_data · array<1>{real}
# │       └── waveform_windowed · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1027203 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_windowed,presum_rate,waveform_presummed,t_sat_lo,t_sat_hi}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── presum_rate · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── t_sat_hi · array<1>{real}
# │       ├── t_sat_lo · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       ├── waveform_presummed · table{t0,dt,values}
# │       │   ├── dt · array<1>{real}
# │       │   ├── t0 · array<1>{real}
# │       │   └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │       │       ├── decoded_size · real
# │       │       └── encoded_data · array<1>{array<1>{real}}
# │       │           ├── cumulative_length · array<1>{real}
# │       │           └── flattened_data · array<1>{real}
# │       └── waveform_windowed · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1052802 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1052803 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1052804 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1052805 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054400 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054401 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054402 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054403 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054404 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1054405 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056000 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056001 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056002 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056003 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056004 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1056005 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,event_type,fcid,crate,slot,board_id,fc_input,waveform_bit_drop}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform_bit_drop · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_encoded_equalsized_arrays<1,1>{real}
# │               ├── decoded_size · real
# │               └── encoded_data · array<1>{array<1>{real}}
# │                   ├── cumulative_length · array<1>{real}
# │                   └── flattened_data · array<1>{real}
# ├── ch1057600 · HDF5 group
# ...
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004816 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004817 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004818 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004819 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004820 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004821 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# ├── ch2004822 · HDF5 group
# │   └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
# │       ├── abs_delta_mu_usec · array<1>{real}
# │       ├── baseline · array<1>{real}
# │       ├── board_id · array<1>{real}
# │       ├── channel · array<1>{real}
# │       ├── crate · array<1>{real}
# │       ├── daqenergy · array<1>{real}
# │       ├── deadtime · array<1>{real}
# │       ├── delta_mu_usec · array<1>{real}
# │       ├── dr_maxticks · array<1>{real}
# │       ├── dr_start_pps · array<1>{real}
# │       ├── dr_start_ticks · array<1>{real}
# │       ├── dr_stop_pps · array<1>{real}
# │       ├── dr_stop_ticks · array<1>{real}
# │       ├── event_type · array<1>{real}
# │       ├── eventnumber · array<1>{real}
# │       ├── fc_input · array<1>{real}
# │       ├── fcid · array<1>{real}
# │       ├── mu_offset_sec · array<1>{real}
# │       ├── mu_offset_usec · array<1>{real}
# │       ├── numtraces · array<1>{real}
# │       ├── packet_id · array<1>{real}
# │       ├── runtime · array<1>{real}
# │       ├── slot · array<1>{real}
# │       ├── timestamp · array<1>{real}
# │       ├── to_master_sec · array<1>{real}
# │       ├── to_start_sec · array<1>{real}
# │       ├── to_start_usec · array<1>{real}
# │       ├── tracelist · array<1>{array<1>{real}}
# │       │   ├── cumulative_length · array<1>{real}
# │       │   └── flattened_data · array<1>{real}
# │       ├── ts_maxticks · array<1>{real}
# │       ├── ts_pps · array<1>{real}
# │       ├── ts_ticks · array<1>{real}
# │       └── waveform · table{t0,dt,values}
# │           ├── dt · array<1>{real}
# │           ├── t0 · array<1>{real}
# │           └── values · array_of_equalsized_arrays<1,1>{real}
# └── ch2004823 · HDF5 group
#     └── raw · table{packet_id,eventnumber,timestamp,runtime,numtraces,tracelist,baseline,daqenergy,channel,ts_pps,ts_ticks,ts_maxticks,mu_offset_sec,mu_offset_usec,to_master_sec,delta_mu_usec,abs_delta_mu_usec,to_start_sec,to_start_usec,dr_start_pps,dr_start_ticks,dr_stop_pps,dr_stop_ticks,dr_maxticks,deadtime,waveform,event_type,fcid,crate,slot,board_id,fc_input}
#         ├── abs_delta_mu_usec · array<1>{real}
#         ├── baseline · array<1>{real}
#         ├── board_id · array<1>{real}
#         ├── channel · array<1>{real}
#         ├── crate · array<1>{real}
#         ├── daqenergy · array<1>{real}
#         ├── deadtime · array<1>{real}
#         ├── delta_mu_usec · array<1>{real}
#         ├── dr_maxticks · array<1>{real}
#         ├── dr_start_pps · array<1>{real}
#         ├── dr_start_ticks · array<1>{real}
#         ├── dr_stop_pps · array<1>{real}
#         ├── dr_stop_ticks · array<1>{real}
#         ├── event_type · array<1>{real}
#         ├── eventnumber · array<1>{real}
#         ├── fc_input · array<1>{real}
#         ├── fcid · array<1>{real}
#         ├── mu_offset_sec · array<1>{real}
#         ├── mu_offset_usec · array<1>{real}
#         ├── numtraces · array<1>{real}
#         ├── packet_id · array<1>{real}
#         ├── runtime · array<1>{real}
#         ├── slot · array<1>{real}
#         ├── timestamp · array<1>{real}
#         ├── to_master_sec · array<1>{real}
#         ├── to_start_sec · array<1>{real}
#         ├── to_start_usec · array<1>{real}
#         ├── tracelist · array<1>{array<1>{real}}
#         │   ├── cumulative_length · array<1>{real}
#         │   └── flattened_data · array<1>{real}
#         ├── ts_maxticks · array<1>{real}
#         ├── ts_pps · array<1>{real}
#         ├── ts_ticks · array<1>{real}
#         └── waveform · table{t0,dt,values}
#             ├── dt · array<1>{real}
#             ├── t0 · array<1>{real}
#             └── values · array_of_equalsized_arrays<1,1>{real}

# %%
start = time.time()
data_init = lh5.read_as(f"/ch{int(chn)}/raw", fft_files, field_mask = ["waveform_presummed"], library="ak")
print("Took", time.time() - start, "s to read")
# Out:
# Took 2.485355854034424 s to read

# %%
wfs = data_init["waveform_presummed"]
wfs_ADC = ak.to_numpy(wfs["values"])

# %%
calcs = fit_baseline_per_event(wfs_ADC)

# %%
n_events = 6

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i in range(n_events):

    wf = wfs_ADC[i]
    t0 = data_init["waveform_presummed"][i]["t0"]
    dt = data_init["waveform_presummed"][i]["dt"]

    # asse tempo (o samples se preferisci)
    timestamp = t0 + np.arange(len(wf)) * dt

    # baseline fit
    x_fit = np.arange(len(wf))
    baseline = calcs["bl_int"][i] + calcs["bl_slope"][i] * x_fit

    ax = axes[i]
    ax.plot(timestamp, wf, label="waveform")
    ax.plot(timestamp, baseline, label="baseline fit")

    ax.set_title(f"Event {i}")
    ax.set_xlabel("timestamp (ns)")
    ax.set_ylabel("ADC")
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# Distirbution of the bl_sòlope parmaeter
# Here i'lll collect the mean and the  sigma in order to build the classifier
from scipy.optimize import curve_fit

counts, bc, _ = plt.hist(calcs["bl_slope"], bins = 400, histtype = 'step')
be = (bc[1:] + bc[:-1])/2

p0 = [max(counts), 0.1, 0.1, 0]
popt, pcov = curve_fit(
        gaussian,
        be,
        counts,
        p0=p0,
        maxfev=5000
    )
mu = popt[1]
sigma = popt[2]

print(popt)
print(np.sqrt(np.diag(pcov)))

plt.plot(be, gaussian(be, *popt), label = f"mu = {popt[1]:.3f}, sigma = {popt[2]:.2f} ")

plt.legend(loc = "upper right")
plt.ylabel(f"Counts")
plt.xlabel("Baseline slope")
plt.title(f"{detector}")
plt.yscale('log')
# Out:
# [8.52390570e+01 1.26743794e-03 5.93609969e-02 7.61936206e-02]
# [7.07342304e-01 5.48182891e-04 6.06935769e-04 2.65717895e-01]

# %%
classifier_bl_slope = (calcs["bl_slope"] - mu) / sigma

counts, bc, _ = plt.hist(classifier_bl_slope, bins = 400, histtype = 'step', label=  "All events")

'''
be = (bc[1:] + bc[:-1])/2
p0 = [max(counts), 0.1, 0.1, 0]
popt, pcov = curve_fit(
        gaussian,
        be,
        counts,
        p0=p0,
        maxfev=5000
    )
mu = popt[1]
sigma = popt[2]

print(popt)
print(np.sqrt(np.diag(pcov)))
plt.plot(be, gaussian(be, *popt), label = f"mu = {popt[1]:.3f}, sigma = {popt[2]:.2f} ")'''

plt.legend(loc = "upper right")
plt.ylabel(f"Counts")
plt.xlabel("classifier Baseline slope")
plt.title(f"{detector}")
plt.yscale('log')
