# %%
import rich
import logging
import glob

import matplotlib.pyplot as plt
import time
import os
import awkward as ak
import numpy as np
import pandas as pd
from lgdo import lh5
from legendmeta import LegendMetadata
from dbetto import Props
from pygama.pargen.AoE_cal import *
from pygama.pargen.AoE_cal import CalAoE, Pol1, SigmaFit, aoe_peak
from pygama.pargen.data_cleaning import get_tcm_pulser_ids
from pygama.pargen.utils import load_data
from tqdm import tqdm
from pathlib import Path
from matplotlib.backends.backend_pdf import PdfPages

import os, json
import pint

u = pint.get_application_registry()


from dspeed.vis.waveform_browser import WaveformBrowser
from legendmeta import LegendMetadata
from dbetto import Props
from pygama.pargen.utils import load_data

# %matplotlib inline

# %% [markdown]
# # RUN 001

# %%
data_path = "/global/cfs/cdirs/m2676/data/lngs/l200/public/prodenv/prod-blind/ref/latest"
config = Props.read_from(os.path.join(data_path, "config.json"), subst_pathvar=True)["setups"]["l200"]["paths"]
meta  = LegendMetadata(config["metadata"])
chmap = meta.channelmap(meta.dataprod.runinfo.p03.r001.phy.start_key)

# %%
data_path
# Out:
# '/global/cfs/cdirs/m2676/data/lngs/l200/public/prodenv/prod-blind/ref/latest'

# %%
# PRENDO I DATI DI FISICA E NON DI CALIBRAZIONE f"{config["tier_psp"]}/cal/p03/r000/*.lh5" ---> f"{config["tier_psp"]}/phy/p03/r000/*.lh5"
pet_file = sorted(glob.glob(f"{config["tier_pet"]}/phy/l200-p03-r001-phy-tier_pet.lh5"))
psp_file = sorted(glob.glob(f"{config["tier_psp"]}/phy/p03/r001/*.lh5")) #access exsiting DSP-processed data such as the energy for partitions
tcm_file = sorted(glob.glob(f"{config["tier_tcm"]}/phy/p03/r001/*.lh5"))  # --> solo per il pulse
raw_file = sorted(glob.glob(f"{config["tier_raw"]}/phy/p03/r001/*.lh5"))

# %% [markdown]
# # cuts --> un solo detector

# %%
plt.rcParams["figure.figsize"] = (14, 4)
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["font.size"] = 14

# %%
channel = f'ch{chmap.V02160A.daq.rawid}'
detector = "V02160A"

# %%
cal_file = f"{config["par_pht"]}/cal/p03/r001/l200-p03-r001-cal-20230317T211819Z-par_pht.json"
cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]

# %%
params = [ "is_valid_bl_slope_classifier",
         "cuspEmax_ctc_cal"]

# %%
# qui mi posso salvare i paramteri di DSP (che ho scelto e definito in config) per lo specfico canale e per tutti gli eventi registrati
start = time.time()
data = load_data(
        files = psp_file,   # da qui prenidmao i dati di dsp già processati 
        lh5_path = f"{channel}/dsp",  # prendo i risultati del dsp per il canale /detcetor specifico
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"],  # lo prendiamo da par_pht
        params=params,
        return_selection_mask=False,)

print(f"[INFO] Took {time.time() - start:.2f} s")
# Out:
# [INFO] Took 27.51 s

# %%
# trigger
trigger_data = lh5.read_as("/evt/trigger", pet_file, library="ak")
data["forced_trigger"] = ak.to_numpy(trigger_data['is_forced'])

# pulsesr and coincidences 
coincident_data = lh5.read_as("/evt/coincident", pet_file, library="ak")
data["is_pulser"] = coincident_data['puls']  # no pulser events
data["is_muon"] = coincident_data['muon_offline']  # no muons
data["is_HPGe"] = coincident_data['geds']  # only events with an HPGe signal

# energy selection
mask_lowe =  (data["cuspEmax_ctc_cal"] >=0 ) & (data["cuspEmax_ctc_cal"] < 500)
data["is_below_500keV"] = mask_lowe

### Discharge
geds_data = lh5.read_as("/evt/geds", pet_file, library="ak")
mask_discharge = geds_data.quality.is_not_bb_like.is_delayed_discharge
data["is_discharge"] = mask_discharge

# %%
m_fix = data["is_HPGe"]&~data["is_muon"]
m_discharge = ~data["is_discharge"]
m_bl_slope_above5 = (data["is_valid_bl_slope_classifier"] > 5)
    
m_pulser = data["is_pulser"]
m_ft = data["forced_trigger"]
m_lowE = data["is_below_500keV"]

# %%
Low_energy_selection =  m_discharge & ~m_pulser & ~m_ft & m_fix & m_lowE & m_bl_slope_above5 
print("voglio vedere vere quali eventi vengono rigettati dai tagli")
print(np.sum(Low_energy_selection), "Low energy events")
# Out:
# voglio vedere vere quali eventi vengono rigettati dai tagli
# 1 Low energy events

# %%
meta.dataprod.runinfo.p03
# Out:
# {'r000': {'cal': {'start_key': '20230311T235840Z'},
#   'phy': {'start_key': '20230312T043356Z', 'livetime_in_s': 443740}},
#  'r001': {'cal': {'start_key': '20230317T211819Z'},
#   'phy': {'start_key': '20230318T015140Z', 'livetime_in_s': 550760}},
#  'r002': {'cal': {'start_key': '20230324T161401Z'},
#   'phy': {'start_key': '20230324T205907Z', 'livetime_in_s': 554660}},
#  'r003': {'cal': {'start_key': '20230331T161141Z'},
#   'phy': {'start_key': '20230401T012732Z', 'livetime_in_s': 446340}},
#  'r004': {'cal': {'start_key': '20230406T192453Z'},
#   'phy': {'start_key': '20230406T235540Z', 'livetime_in_s': 463040}},
#  'r005': {'cal': {'start_key': '20230412T124030Z'},
#   'phy': {'start_key': '20230412T171450Z', 'livetime_in_s': 58160}}}

# %%
dsp_config = meta.dataprod.config.tier_dsp['l200-p01-r%-T%-ICPC-dsp_proc_chain']
print("Available processors:", list(dsp_config['processors'].keys()))
dsp_overrides = meta.dataprod.overrides.dsp.on(meta.dataprod.runinfo.p03.r000.cal.start_key).ch1104000
# Out:
# Available processors: ['wf_presum', 'tp_min, tp_max, wf_min, wf_max', 'wf_mean , wf_std, wf_slope, wf_intercept', 'wf_slope_diff , wf_slope_rms', 'tp_min_win, tp_max_win, wf_min_win, wf_max_win', 'bl_mean_win , bl_std_win, bl_slope_win, bl_intercept_win', 'wf_blsub_win', 'wf_pz_win', 't0_kernel', 'wf_t0_filter', 'wf_atrap', 'wf_t0_smooth', 'conv_tmin ,tp_start, conv_min, conv_max', 'tp_0_atrap', 'tp_0_est', 'bl_mean , bl_std, bl_slope, bl_intercept', 'bl_slope_diff , bl_slope_rms', 'wf_logged', 'wf_blsub', 'tail_pars', 'tail_slope', 'tail_diff, tail_rms', 'wf_pz', 'pz_mean , pz_std, pz_slope, pz_intercept', 'pz_slope_diff, pz_slope_rms', 'dwt_haar', 'dwt_tp_min, dwt_tp_max, dwt_min, dwt_max', 'dwt_norm', 'svm_label', 'wf_trap', 'tp_trapTmin, tp_trapTmax, trapTmin, trapTmax', 'trapTftp', 'wf_trap_short', 'trapSmax', 'wf_pileup_trap', 'baselineEmax', 'tailEmax', 'wf_rc_cr2', 'pos_rc_cr2_thresh', 'neg_rc_cr2_thresh', 'rc_cr2_pileup_n_crossings, rc_cr2_pileup_polarity, rc_cr2_pileup_idxs', 'wf_etrap', 'trapEmax', 'trapEftp', 'cusp_kernel', 'wf_cusp', 'cuspTmin, cuspTmax, cuspEmin, cuspEmax', 'cuspEftp', 'zac_kernel', 'wf_zac', 'zacEmax', 'zacEftp', 'step_kernel', 'wf_step', 'centroid', 'wf_align', 'wf_dplms', 'dplmsEmax', 'dplmsEftp', 'tp_100', 'tp_99', 'tp_95', 'tp_90', 'tp_80', 'tp_50', 'tp_20', 'tp_10', 'tp_01', 'wf_qtrap', 'trapQftp', 'QDrift', 'dt_eff', 'wf_curr_window', 'curr', 'tp_curr_min, tp_curr_max, curr_min, curr_max', 'curr_up', 'curr_av', 'aoe_t_min, tp_aoe_max, A_min, A_max', 'wf_tri', 'aoe_t_min_tri, tp_aoe_max_tri, A_min_tri, A_max_tri', 'slope200_kernel', 'wf_slope200', 'aoe_t_min_slope200, tp_aoe_max_slope200, A_min_slope200, A_max_slope200', 'wf_up', 'wf_av', 'upslope200_kernel', 'wf_upslope200', 'tp_aoe_min_upslope200, tp_aoe_max_upslope200, A_min_upslope200, A_max_upslope200', 'tp_80_lq', 'wf_trap_lq', 'lq80', 'wf_invert', 'wf_win_invert', 't_discharge', 'wf_t0_invert', 'wf_t0_invert_smooth', 'conv_tmin_invert ,tp_start_invert, conv_min_invert, conv_max_invert', 'tp_0_invert', 'wf_trap_invert', 'trapTmax_invert', 'trapTftp_invert', 'cuspEftp_invert', 'tp_100_invert', 'tp_99_invert', 'tp_95_invert', 'tp_90_invert', 'tp_80_invert', 'tp_50_invert', 'tp_20_invert', 'tp_10_invert', 'wf_qdrift_invert', 'trapQftp_invert', 'QDrift_invert', 'dt_eff_invert', 'dcrRaw_tpk_1', 'dcrRaw_tpk_2', 'dcrRaw_tpk_3', 'dcrRaw_tpk_4', 'wf_lsf', 'dcrRaw_lsf_mean_1,dcrRaw_lsf_std_1,dcrRaw_lsf_slope_1,dcrRaw_lsf_intercept_1', 'dcrRaw_lsf_mean_2,dcrRaw_lsf_std_2,dcrRaw_lsf_slope_2,dcrRaw_lsf_intercept_2', 'dcrRaw_lsf_mean_3,dcrRaw_lsf_std_3,dcrRaw_lsf_slope_3,dcrRaw_lsf_intercept_3', 'dcrRaw_lsf_mean_4,dcrRaw_lsf_std_4,dcrRaw_lsf_slope_4,dcrRaw_lsf_intercept_4']

# %%
print(list(meta.dataprod.config.tier_dsp.keys()))
# Out:
# ['l200-p02-r%-T%-SiPM-dsp_proc_chain', 'l200-p01-r%-T%-COAX-dsp_proc_chain', 'l200-p01-r%-T%-SiPM-dsp_proc_chain', 'l200-p01-r%-T%-ICPC-dsp_proc_chain', 'l200-p02-r%-T%-MUON-dsp_proc_chain']

# %%
browser = WaveformBrowser(
    raw_file,
    f"{channel}/raw",
    dsp_config=dsp_config,  # Need to include a dsp config file!
    database=dsp_overrides,
    lines=["wf_blsub"],
    aux_values=data,   # dsp data
    #lines=["waveform_presummed"],
    legend=["E = {cuspEmax_ctc_cal} keV"],
    #legend_opts={"loc": "upper left"},
    #legend=["A/E = {AoE_Classifier}"],  # values to put in the legend
    entry_mask=Low_energy_selection,  # apply cut
    n_drawn=3,  # number to draw for draw_next
)

browser.draw_next()

plt.ylabel("Signal (ADC)")
plt.xlabel("Time (ns)")
plt.grid(alpha = 0.25, ls = '--')
# Out:
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)

# %% [markdown]
# # All the detectors run 001

# %% [markdown]
# # BL SLOPE

# %%
cal = Props.read_from(cal_file)

# %%
# tra tutti i detector che ci sono prendo solo quelli con lo stato di 
# usability = 'on' oppure 'ac'
# processability = True

chmap = meta.channelmap(meta.dataprod.runinfo.p03.r001.phy.start_key)
geds = chmap.group("system").geds

chmap_ak = ak.Array(geds.values())

rawids = ak.to_numpy(chmap_ak.daq.rawid)
names = ak.to_numpy(chmap_ak["name"]).astype(str)

# Leggi la usability di ciascun detector
usability = np.array([
    getattr(det.analysis, "usability", None)
    for det in geds.values()
])

# Tieni tutto tranne i detector con usability == "off"
mask_not_off = (usability != "off")

# (Opzionale) Controlla quali stati sono presenti
print("Usability presenti:", np.unique(usability))

# Maschere per tipo di detector, escludendo solo gli "off"
masks_name = {
    "ICPC": np.char.startswith(names, "V") & mask_not_off,
    "BEGe": np.char.startswith(names, "B") & mask_not_off,
    "Coax": np.char.startswith(names, "C") & mask_not_off,
    "PPC":  np.char.startswith(names, "P") & mask_not_off,
}
det_names = ["ICPC", "BEGe", "Coax", "PPC"]
# Out:
# Usability presenti: ['ac' 'off' 'on']

# %%
channels_rawid = {
    det_type: [f"ch{rid}" for rid in rawids[mask]]
    for det_type, mask in masks_name.items()
}

channels_names = {
    det_type: names[mask].tolist()
    for det_type, mask in masks_name.items()
}

print("\nExcluded channels (usability='off' OR processable=False):")

for ch, det in geds.items():

    usability = getattr(det.analysis, "usability", None)
    processable = getattr(det.analysis, "processable", None)

    if (usability == "off") or (processable is False):

        print(
            f"channel={ch:3d} | "
            f"rawid=ch{det.daq.rawid:5d} | "
            f"name={det.name:20s} | "
            f"usability={usability} | "
            f"processable={processable}"
        )

# Riassunto
for det_type in channels_names:
    print(f"\n{det_type}: {len(channels_names[det_type])} detector")
    print(channels_names[det_type])
# Out:
# Excluded channels (usability='off' OR processable=False):
# channel= 17 | rawid=ch1108804 | name=V07298B              | usability=off | processable=False
# channel= 21 | rawid=ch1110405 | name=P00665A              | usability=off | processable=False
# channel= 34 | rawid=ch1115200 | name=V01386A              | usability=off | processable=False
# channel= 35 | rawid=ch1115201 | name=V01403A              | usability=off | processable=False
# channel= 36 | rawid=ch1115202 | name=V01404A              | usability=off | processable=False
# channel= 64 | rawid=ch1080002 | name=B00091D              | usability=off | processable=False
# channel= 65 | rawid=ch1080003 | name=P00537A              | usability=off | processable=False
# channel= 74 | rawid=ch1083200 | name=B00091B              | usability=off | processable=False
# channel= 91 | rawid=ch1088000 | name=P00538B              | usability=off | processable=False
# channel= 95 | rawid=ch1088004 | name=P00661A              | usability=off | processable=False
# channel= 98 | rawid=ch1089602 | name=P00665B              | usability=off | processable=False
# channel=100 | rawid=ch1089604 | name=P00698B              | usability=off | processable=False
#
# ICPC: 37 detector
# ['V02160A', 'V02160B', 'V05261B', 'V05266A', 'V05266B', 'V05268B', 'V05612A', 'V07647A', 'V07647B', 'V00074A', 'V04549A', 'V01406A', 'V01415A', 'V08682B', 'V08682A', 'V09372A', 'V09374A', 'V09724A', 'V02162B', 'V02166B', 'V04199A', 'V04545A', 'V05267B', 'V07646A', 'V07302B', 'V00048B', 'V00050A', 'V00050B', 'V01387A', 'V05261A', 'V05268A', 'V07302A', 'V00048A', 'V01240A', 'V01389A', 'V05267A', 'V05612B']
#
# BEGe: 26 detector
# ['B00035C', 'B00032B', 'B00091C', 'B00000B', 'B00000C', 'B00061A', 'B00061C', 'B00076C', 'B00079B', 'B00079C', 'B00089C', 'B00089D', 'B00002A', 'B00089A', 'B00091A', 'B00000D', 'B00002C', 'B00032C', 'B00032D', 'B00035A', 'B00035B', 'B00061B', 'B00089B', 'B00000A', 'B00002B', 'B00032A']
#
# Coax: 6 detector
# ['C000RG1', 'C000RG2', 'C00ANG3', 'C00ANG5', 'C00ANG2', 'C00ANG4']
#
# PPC: 20 detector
# ['P00574B', 'P00698A', 'P00712A', 'P00909C', 'P00661B', 'P00574A', 'P00538A', 'P00573A', 'P00661C', 'P00662C', 'P00664A', 'P00665C', 'P00748B', 'P00909B', 'P00573B', 'P00575A', 'P00574C', 'P00662A', 'P00662B', 'P00748A']

# %%
cal_file = f"{config["par_pht"]}/cal/p03/r001/l200-p03-r001-cal-20230317T211819Z-par_pht.json"
trigger_data = lh5.read_as("/evt/trigger", pet_file, library="ak")
coincident_data = lh5.read_as("/evt/coincident", pet_file, library="ak")

# %%
dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]

detector_type = "ICPC"
output_pdf = "waveforms_ICPC_r01.pdf"
params = [
    "is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    "cuspEmax_ctc_cal"
]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])

channels_list = channels_rawid[detector_type]

with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_bl_slope = bl_slope > 5
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_bl_slope
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=["wf_blsub"],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
    
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (ns)")
        plt.grid(alpha=0.25, ls="--")

        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)
        print("======= FINISHED ==============")
# Out:
# 0it [00:00, ?it/s]
# ==================================== ch1104000 1/37 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 1it [00:14, 14.77s/it]
# ======= FINISHED ==============
#
# ==================================== ch1104001 2/37 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 2it [00:29, 14.67s/it]
# ======= FINISHED ==============
#
# ==================================== ch1104002 3/37 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 3it [00:44, 14.83s/it]
# ======= FINISHED ==============
#
# ==================================== ch1104003 4/37 ====================================
# 4it [00:54, 13.15s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1104004 5/37 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 5it [01:10, 13.86s/it]
# ======= FINISHED ==============
#
# ==================================== ch1104005 6/37 ====================================
# 6it [01:21, 13.04s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1105600 7/37 ====================================
# 7it [01:31, 12.10s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1105602 8/37 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 8it [01:44, 12.19s/it]
# ======= FINISHED ==============
#
# ==================================== ch1105603 9/37 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 9it [01:58, 12.81s/it]
# ======= FINISHED ==============
#
# ==================================== ch1108802 10/37 ====================================
#
# 49 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 10it [02:23, 16.65s/it]
# ======= FINISHED ==============
#
# ==================================== ch1108803 11/37 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 11it [02:40, 16.75s/it]
# ======= FINISHED ==============
#
# ==================================== ch1115203 12/37 ====================================
# 12it [03:00, 17.80s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1115204 13/37 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 13it [03:29, 21.02s/it]
# ======= FINISHED ==============
#
# ==================================== ch1116801 14/37 ====================================
#
# 37 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 14it [03:49, 20.76s/it]
# ======= FINISHED ==============
#
# ==================================== ch1116802 15/37 ====================================
#
# 25 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 15it [04:09, 20.61s/it]
# ======= FINISHED ==============
#
# ==================================== ch1116803 16/37 ====================================
#
# 49 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 16it [04:29, 20.51s/it]
# ======= FINISHED ==============
#
# ==================================== ch1116804 17/37 ====================================
#
# 40 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 17it [04:51, 21.02s/it]
# ======= FINISHED ==============
#
# ==================================== ch1116805 18/37 ====================================
#
# 9 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 18it [05:09, 20.10s/it]
# ======= FINISHED ==============
#
# ==================================== ch1118402 19/37 ====================================
#
# 10 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 19it [05:27, 19.43s/it]
# ======= FINISHED ==============
#
# ==================================== ch1118403 20/37 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 20it [05:44, 18.61s/it]
# ======= FINISHED ==============
#
# ==================================== ch1118404 21/37 ====================================
#
# 12 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 21it [05:59, 17.37s/it]
# ======= FINISHED ==============
#
# ==================================== ch1118405 22/37 ====================================
#
# 22 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 22it [06:15, 17.11s/it]
# ======= FINISHED ==============
#
# ==================================== ch1120000 23/37 ====================================
#
# 33 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 23it [06:32, 17.10s/it]
# ======= FINISHED ==============
#
# ==================================== ch1120001 24/37 ====================================
#
# 30 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 24it [06:52, 17.83s/it]
# ======= FINISHED ==============
#
# ==================================== ch1120002 25/37 ====================================
#
# 8 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 25it [07:09, 17.71s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121600 26/37 ====================================
#
# 6 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 26it [07:27, 17.85s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121601 27/37 ====================================
#
# 6 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 27it [07:43, 17.20s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121602 28/37 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 28it [08:13, 21.05s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121603 29/37 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 29it [08:29, 19.64s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121604 30/37 ====================================
#
# 282 Low energy events
# 30it [08:51, 20.21s/it]
# ======= FINISHED ==============
#
# ==================================== ch1121605 31/37 ====================================
#
# 12 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 31it [09:10, 19.89s/it]
# ======= FINISHED ==============
#
# ==================================== ch1078400 32/37 ====================================
#
# 12 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 32it [09:41, 23.30s/it]
# ======= FINISHED ==============
#
# ==================================== ch1084803 33/37 ====================================
#
# 38 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 33it [10:13, 25.90s/it]
# ======= FINISHED ==============
#
# ==================================== ch1084804 34/37 ====================================
# 34it [10:27, 22.27s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1084805 35/37 ====================================
#
# 6 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 35it [10:43, 20.24s/it]
# ======= FINISHED ==============
#
# ==================================== ch1086400 36/37 ====================================
#
# 32 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 36it [11:00, 19.50s/it]
# ======= FINISHED ==============
#
# ==================================== ch1086401 37/37 ====================================
#
# 14 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 37it [11:20, 18.38s/it]
# ======= FINISHED ==============

# %%
dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_bege_R001.pdf"
detector_type = "BEGe"
params = [
    "is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    "cuspEmax_ctc_cal"
]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])

channels_list = channels_rawid[detector_type]

with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_bl_slope = bl_slope > 5
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_bl_slope
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=["wf_blsub"],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
    
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (s)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)
# Out:
# 0it [00:00, ?it/s]
# ==================================== ch1107202 1/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 1it [00:20, 20.99s/it]
# ==================================== ch1110402 2/26 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 2it [00:42, 21.51s/it]
# ==================================== ch1110403 3/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 3it [00:56, 18.01s/it]
# ==================================== ch1112005 4/26 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 4it [01:16, 18.55s/it]
# ==================================== ch1113600 5/26 ====================================
#
# 5 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 5it [01:34, 18.40s/it]
# ==================================== ch1113601 6/26 ====================================
#
# 9 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 6it [01:53, 18.59s/it]
# ==================================== ch1113602 7/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 7it [02:08, 17.54s/it]
# ==================================== ch1113603 8/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 8it [02:23, 16.62s/it]
# ==================================== ch1113604 9/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 9it [02:38, 16.09s/it]
# ==================================== ch1113605 10/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 10it [02:53, 15.73s/it]
# ==================================== ch1120003 11/26 ====================================
#
# 8 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 11it [03:16, 18.03s/it]
# ==================================== ch1120004 12/26 ====================================
#
# 5 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 12it [03:31, 17.03s/it]
# ==================================== ch1078405 13/26 ====================================
# 13it [03:41, 15.13s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1080000 14/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 14it [03:57, 15.18s/it]
# ==================================== ch1080001 15/26 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 15it [04:11, 15.03s/it]
# ==================================== ch1083201 16/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 16it [04:37, 18.11s/it]
# ==================================== ch1083202 17/26 ====================================
# 17it [04:47, 15.86s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1083203 18/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 18it [05:01, 15.29s/it]
# ==================================== ch1083204 19/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 19it [05:22, 16.90s/it]
# ==================================== ch1083205 20/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 20it [05:35, 15.91s/it]
# ==================================== ch1084800 21/26 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 21it [05:49, 15.22s/it]
# ==================================== ch1084801 22/26 ====================================
# 22it [05:59, 13.66s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1084802 23/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 23it [06:12, 13.45s/it]
# ==================================== ch1086403 24/26 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 24it [06:27, 13.78s/it]
# ==================================== ch1086404 25/26 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 25it [06:41, 13.87s/it]
# ==================================== ch1086405 26/26 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 26it [06:55, 15.99s/it]

# %%
import os
os.getcwd()
# Out:
# '/global/u2/r/ritaferi'

# %%
dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_ppc_R001.pdf"
detector_type = "PPC"
params = [
    "is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    "cuspEmax_ctc_cal"
]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])

channels_list = channels_rawid[detector_type]

with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_bl_slope = bl_slope > 5
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_bl_slope
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=["wf_blsub"],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
    
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (s)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)
# Out:
# 0it [00:00, ?it/s]
# ==================================== ch1110404 1/20 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 1it [00:13, 13.04s/it]
# ==================================== ch1112000 2/20 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 2it [00:26, 13.54s/it]
# ==================================== ch1112001 3/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 3it [00:40, 13.51s/it]
# ==================================== ch1112002 4/20 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 4it [00:54, 13.74s/it]
# ==================================== ch1112003 5/20 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 5it [01:08, 13.87s/it]
# ==================================== ch1112004 6/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 6it [01:22, 14.01s/it]
# ==================================== ch1080004 7/20 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 7it [01:37, 14.07s/it]
# ==================================== ch1080005 8/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 8it [01:50, 13.97s/it]
# ==================================== ch1081600 9/20 ====================================
# 9it [02:01, 12.80s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1081601 10/20 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 10it [02:15, 13.22s/it]
# ==================================== ch1081602 11/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 11it [02:29, 13.41s/it]
# ==================================== ch1081603 12/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 12it [02:42, 13.48s/it]
# ==================================== ch1081604 13/20 ====================================
#
# 8 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 13it [02:56, 13.67s/it]
# ==================================== ch1081605 14/20 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 14it [03:11, 13.88s/it]
# ==================================== ch1088001 15/20 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 15it [03:26, 14.17s/it]
# ==================================== ch1088002 16/20 ====================================
#
# 53 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 16it [03:41, 14.60s/it]
# ==================================== ch1088003 17/20 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 17it [03:55, 14.50s/it]
# ==================================== ch1089600 18/20 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 18it [04:10, 14.53s/it]
# ==================================== ch1089601 19/20 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 19it [04:24, 14.36s/it]
# ==================================== ch1089603 20/20 ====================================
#
# 8 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 20it [04:39, 13.99s/it]

# %%
# coax


dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_coax_R001.pdf"
detector_type = "Coax"
params = [
    "is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    "cuspEmax_ctc_cal"
]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])

channels_list = channels_rawid[detector_type][:3]

with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_bl_slope = bl_slope > 5
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_bl_slope
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
        
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=["wf_blsub"],
            aux_values=data,
            legend = None if n_selected > 10 else ["E = {cuspEmax_ctc_cal:.1f} keV"],
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
    
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (s)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)
# Out:
# 0it [00:00, ?it/s]
# ==================================== ch1107203 1/3 ====================================
# 1it [00:10, 10.44s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1107204 2/3 ====================================
#
# 31 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 2it [00:23, 12.17s/it]
# ==================================== ch1107205 3/3 ====================================
#
# 37 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 3it [00:38, 12.70s/it]

# %% [markdown]
# # bl_slope_RMS

# %%
channels_tot = []

for ch, det in geds.items():

    usability = getattr(det.analysis, "usability", None)
    processable = getattr(det.analysis, "processable", None)

    if usability in ("on", "ac"):
        channels_tot.append(f"ch{det.daq.rawid}")

# %%
# coax


dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_bl_slope_RMS_R001.pdf"
params = [
    #"is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    "is_valid_bl_slope_rms_classifier",
    "is_valid_bl_slope_rms",
    "cuspEmax_ctc_cal"
]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])
channels_list = channels_tot
with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope"]

        bl_slope_rms_class = data["is_valid_bl_slope_rms_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_qc = bl_slope 

        m_bl_slope_rms = bl_slope_rms_class > 5  # taglio per guardare gli eventi che verrebbero rigettati dal taglio in analisi
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_qc &
            m_bl_slope_rms
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=["wf_blsub"],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            legend_opts={"loc": "lower right"},
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (s)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)

print("=======================  finished ===========================")
# Out:
# 0it [00:00, ?it/s]
# ==================================== ch1104000 1/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 1it [00:32, 32.98s/it]
# ==================================== ch1104001 2/89 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 2it [00:47, 22.39s/it]
# ==================================== ch1104002 3/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 3it [01:01, 18.41s/it]
# ==================================== ch1104003 4/89 ====================================
# 4it [01:11, 14.88s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1104004 5/89 ====================================
# 5it [01:19, 12.59s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1104005 6/89 ====================================
#
# 48 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 6it [01:33, 13.16s/it]
# ==================================== ch1105600 7/89 ====================================
#
# 3 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 7it [01:46, 13.11s/it]
# ==================================== ch1105602 8/89 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 8it [01:59, 13.05s/it]
# ==================================== ch1105603 9/89 ====================================
# 9it [02:09, 11.85s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1107202 10/89 ====================================
# 10it [02:16, 10.65s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1107203 11/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 11it [02:30, 11.48s/it]
# ==================================== ch1107204 12/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 12it [02:44, 12.34s/it]
# ==================================== ch1107205 13/89 ====================================
# 13it [02:56, 12.12s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1108800 14/89 ====================================
# 14it [03:07, 11.86s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1108801 15/89 ====================================
# 15it [03:18, 11.48s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1108802 16/89 ====================================
#
# 21 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 16it [03:36, 13.59s/it]
# ==================================== ch1108803 17/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 17it [03:53, 14.63s/it]
# ==================================== ch1110402 18/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 18it [04:13, 16.20s/it]
# ==================================== ch1110403 19/89 ====================================
# 19it [04:23, 14.27s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1110404 20/89 ====================================
# 20it [04:32, 12.61s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1112000 21/89 ====================================
# 21it [04:40, 11.33s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1112001 22/89 ====================================
#
# 2 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 22it [04:57, 12.93s/it]
# ==================================== ch1112002 23/89 ====================================
# 23it [05:09, 12.66s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1112003 24/89 ====================================
# 24it [05:22, 12.97s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1112004 25/89 ====================================
# 25it [05:33, 12.40s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1112005 26/89 ====================================
#
# 1 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 26it [05:49, 13.45s/it]
# ==================================== ch1113600 27/89 ====================================
# 27it [06:00, 12.67s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1113601 28/89 ====================================
# 28it [06:10, 11.99s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1113602 29/89 ====================================
# 29it [06:21, 11.55s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1113603 30/89 ====================================
# 30it [06:31, 11.16s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1113604 31/89 ====================================
# 31it [06:42, 10.93s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1113605 32/89 ====================================
# 32it [06:52, 10.69s/it]
# 0 Low energy events
# No events → skipping channel
#
# ==================================== ch1115203 33/89 ====================================
#
# 4 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 33it [07:16, 14.68s/it]
# ==================================== ch1115204 34/89 ====================================
#
# 6 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 34it [07:31, 14.96s/it]
# ==================================== ch1116801 35/89 ====================================
#
# 8 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 35it [07:49, 15.65s/it]
# ==================================== ch1116802 36/89 ====================================
#
# 83 Low energy events
# /opt/conda/lib/python3.12/site-packages/dspeed/processing_chain.py:1571: RuntimeWarning: invalid value encountered in divide
#   self.processor(*self.args, **self.kwargs)
# 36it [08:05, 15.99s/it]
# ==================================== ch1116803 37/89 ====================================
#
# 79 Low energy events
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# idx indexed past the end of the array in the file. Culling...
# 36it [08:20, 13.89s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 114
#     112 n = n_selected
#     113 colors = cmap(np.linspace(0.3, 0.95, n))
# --> 114 browser = WaveformBrowser(
#     115     raw_file,
#     116     f"{channel}/raw",
#     117     dsp_config=dsp_config,
#     118     database=dsp_overrides,
#     119     lines=["wf_blsub"],
#     120     aux_values=data,
#     121     legend=["E = {cuspEmax_ctc_cal} keV"],
#     122     legend_opts={"loc": "lower right"},
#     123     entry_mask=low_energy_selection,
#     124     n_drawn=n_selected,
#     125     styles={"color": colors}
#     126 )
#     128 browser.draw_next()
#     129 plt.title(f"chn : {channel}")
#
# File /opt/conda/lib/python3.12/site-packages/dspeed/vis/waveform_browser.py:176, in WaveformBrowser.__init__(self, files_in, lh5_group, base_path, entry_list, entry_mask, dsp_config, database, aux_values, lines, styles, legend, legend_opts, n_drawn, x_unit, x_lim, y_lim, norm, align, buffer_len, block_width)
#     165     self.lh5_it = LH5Iterator(
#     166         files_in,
#     167         lh5_group,
#    (...)
#     172         buffer_len=buffer_len,
#     173     )
#     175 # Get the input buffer and read the first chunk
# --> 176 self.lh5_in, _ = self.lh5_it.read(0)
#     178 self.aux_vals = aux_values
#     179 # Apply entry selection to aux_vals if needed
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/iterator.py:347, in LH5Iterator.read(self, i_entry)
#     344     continue
#     346 i_local = local_i_entry if local_idx is None else local_idx[local_i_entry]
# --> 347 self.lh5_buffer, n_rows = self.lh5_st.read(
#     348     self.groups[i_file],
#     349     self.lh5_files[i_file],
#     350     start_row=i_local,
#     351     n_rows=self.buffer_len - self.n_rows,
#     352     idx=local_idx,
#     353     field_mask=self.field_mask,
#     354     obj_buf=self.lh5_buffer,
#     355     obj_buf_start=self.n_rows,
#     356 )
#     358 self.n_rows += n_rows
#     359 i_file += 1
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/store.py:239, in LH5Store.read(self, name, lh5_file, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress, **file_kwargs)
#     236 if isinstance(idx, np.ndarray) and idx.dtype == np.dtype("?"):
#     237     idx = np.where(idx)[0]
# --> 239 return _serializers._h5_read_lgdo(
#     240     lh5_obj.id,
#     241     lh5_obj.file.filename,
#     242     lh5_obj.name,
#     243     start_row=start_row,
#     244     n_rows=n_rows,
#     245     idx=idx,
#     246     use_h5idx=use_h5idx,
#     247     field_mask=field_mask,
#     248     obj_buf=obj_buf,
#     249     obj_buf_start=obj_buf_start,
#     250     decompress=decompress,
#     251 )
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/composite.py:104, in _h5_read_lgdo(h5o, fname, oname, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress)
#     101         idx = idxa[:n_rows]  # works even if n_rows > len(idxa)
#     103 if lgdotype is Table:
# --> 104     return _h5_read_table(
#     105         h5o,
#     106         fname,
#     107         oname,
#     108         start_row=start_row,
#     109         n_rows=n_rows,
#     110         idx=idx,
#     111         use_h5idx=use_h5idx,
#     112         field_mask=field_mask,
#     113         obj_buf=obj_buf,
#     114         obj_buf_start=obj_buf_start,
#     115         decompress=decompress,
#     116     )
#     118 if lgdotype is Histogram:
#     119     return _h5_read_histogram(
#     120         h5o,
#     121         fname,
#    (...)
#     130         decompress=decompress,
#     131     )
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/composite.py:305, in _h5_read_table(h5g, fname, oname, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress)
#     302     fld_buf = obj_buf[field]
#     304 h5o = h5py.h5o.open(h5g, field.encode("utf-8"))
# --> 305 col_dict[field], n_rows_read = _h5_read_lgdo(
#     306     h5o,
#     307     fname,
#     308     f"{oname}/{field}",
#     309     start_row=start_row,
#     310     n_rows=n_rows,
#     311     idx=idx,
#     312     use_h5idx=use_h5idx,
#     313     obj_buf=fld_buf,
#     314     obj_buf_start=obj_buf_start,
#     315     field_mask=submask,
#     316     decompress=decompress,
#     317 )
#     318 h5o.close()
#     320 if obj_buf is not None and obj_buf_start + n_rows_read > len(obj_buf):
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/composite.py:104, in _h5_read_lgdo(h5o, fname, oname, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress)
#     101         idx = idxa[:n_rows]  # works even if n_rows > len(idxa)
#     103 if lgdotype is Table:
# --> 104     return _h5_read_table(
#     105         h5o,
#     106         fname,
#     107         oname,
#     108         start_row=start_row,
#     109         n_rows=n_rows,
#     110         idx=idx,
#     111         use_h5idx=use_h5idx,
#     112         field_mask=field_mask,
#     113         obj_buf=obj_buf,
#     114         obj_buf_start=obj_buf_start,
#     115         decompress=decompress,
#     116     )
#     118 if lgdotype is Histogram:
#     119     return _h5_read_histogram(
#     120         h5o,
#     121         fname,
#    (...)
#     130         decompress=decompress,
#     131     )
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/composite.py:305, in _h5_read_table(h5g, fname, oname, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress)
#     302     fld_buf = obj_buf[field]
#     304 h5o = h5py.h5o.open(h5g, field.encode("utf-8"))
# --> 305 col_dict[field], n_rows_read = _h5_read_lgdo(
#     306     h5o,
#     307     fname,
#     308     f"{oname}/{field}",
#     309     start_row=start_row,
#     310     n_rows=n_rows,
#     311     idx=idx,
#     312     use_h5idx=use_h5idx,
#     313     obj_buf=fld_buf,
#     314     obj_buf_start=obj_buf_start,
#     315     field_mask=submask,
#     316     decompress=decompress,
#     317 )
#     318 h5o.close()
#     320 if obj_buf is not None and obj_buf_start + n_rows_read > len(obj_buf):
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/composite.py:134, in _h5_read_lgdo(h5o, fname, oname, start_row, n_rows, idx, use_h5idx, field_mask, obj_buf, obj_buf_start, decompress)
#     119     return _h5_read_histogram(
#     120         h5o,
#     121         fname,
#    (...)
#     130         decompress=decompress,
#     131     )
#     133 if lgdotype is ArrayOfEncodedEqualSizedArrays:
# --> 134     return _h5_read_array_of_encoded_equalsized_arrays(
#     135         h5o,
#     136         fname,
#     137         oname,
#     138         start_row=start_row,
#     139         n_rows=n_rows,
#     140         idx=idx,
#     141         use_h5idx=use_h5idx,
#     142         obj_buf=obj_buf,
#     143         obj_buf_start=obj_buf_start,
#     144         decompress=decompress,
#     145     )
#     147 if lgdotype is VectorOfEncodedVectors:
#     148     return _h5_read_vector_of_encoded_vectors(
#     149         h5o,
#     150         fname,
#    (...)
#     158         decompress=decompress,
#     159     )
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/encoded.py:30, in _h5_read_array_of_encoded_equalsized_arrays(h5g, fname, oname, **kwargs)
#      24 def _h5_read_array_of_encoded_equalsized_arrays(
#      25     h5g,
#      26     fname,
#      27     oname,
#      28     **kwargs,
#      29 ):
# ---> 30     return _h5_read_encoded_array(
#      31         ArrayOfEncodedEqualSizedArrays, h5g, fname, oname, **kwargs
#      32     )
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/encoded.py:97, in _h5_read_encoded_array(lgdotype, h5g, fname, oname, start_row, n_rows, idx, use_h5idx, obj_buf, obj_buf_start, decompress)
#      95 # read out encoded_data, a VectorOfVectors
#      96 h5o = h5py.h5o.open(h5g, b"encoded_data")
# ---> 97 encoded_data, n_rows_read = _h5_read_vector_of_vectors(
#      98     h5o,
#      99     fname,
#     100     f"{oname}/encoded_data",
#     101     start_row=start_row,
#     102     n_rows=n_rows,
#     103     idx=idx,
#     104     use_h5idx=use_h5idx,
#     105     obj_buf=None if decompress else encoded_data_buf,
#     106     obj_buf_start=0 if decompress else obj_buf_start,
#     107 )
#     108 h5o.close()
#     110 # return the still encoded data in the buffer object, if there
#
# File /opt/conda/lib/python3.12/site-packages/lgdo/lh5/_serializers/read/vector_of_vectors.py:98, in _h5_read_vector_of_vectors(h5g, fname, oname, start_row, n_rows, idx, use_h5idx, obj_buf, obj_buf_start)
#      92     fd_idx = _make_fd_idx(fd_starts, this_cumulen_nda, fd_idx)
#      94     # Now clean up this_cumulen_nda, to be ready
#      95     # to match the in-memory version of flattened_data. Note: these
#      96     # operations on the view change the original array because they are
#      97     # numpy arrays, not lists.
# ---> 98     this_cumulen_nda[-len(fd_starts) :] -= fd_starts
#      99     np.cumsum(this_cumulen_nda, out=this_cumulen_nda)
#     101 else:
#
# ValueError: non-broadcastable output operand with shape (1,) doesn't match the broadcast shape (2,)

# %% [markdown]
# # taill rms

# %%
channels_tot;

# %%
dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_tail_RMS_R001.pdf"
params = [
    #"is_valid_bl_slope_classifier",
    "is_valid_bl_slope",
    #"is_valid_bl_slope_rms_classifier",
    "is_valid_bl_slope_rms",
    "is_valid_tail_rms_classifier",
    "is_valid_tail_rms",
    "cuspEmax_ctc_cal"
]
#channels_list = channels_rawid[detector_type]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])
channels_list = channels_tot
with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_250keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 250)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_250keV = data["is_below_250keV"]
        bl_slope = data["is_valid_bl_slope"]
        bl_slope_rms_class = data["is_valid_bl_slope_rms"]

        tail_rms_class = data["is_valid_tail_rms_classifier"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_qc = bl_slope & bl_slope_rms_class

        m_tail_rms = tail_rms_class > 5  # taglio per guardare gli eventi che verrebbero rigettati dal taglio in analisi
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_250keV &
            m_qc &
            m_tail_rms
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=[#"wf_blsub",
                    "wf_pz"],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            legend_opts={"loc": "lower right"},
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
        )
    
        browser.draw_next()
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (ns)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)

print("=======================  finished ===========================")

# %% [markdown]
# # trap TpMAX

# %%
meta.dataprod.config.tier_dsp
# Out:
# TextDB('/global/cfs/cdirs/m2676/data/lngs/l200/public/prodenv/prod-blind/ref/v2.1.5/inputs/dataprod/config/tier_dsp')

# %%
dsp_config = meta.dataprod.config.tier_dsp[
    'l200-p01-r%-T%-ICPC-dsp_proc_chain'
]
output_pdf = "waveforms_tp_TrapMax_passed_R001.pdf"
params = [
    "is_valid_bl_slope",
    "is_valid_bl_slope_rms",
    "is_valid_tail_rms",
    "is_not_noise_burst",
    "is_valid_cuspEmin",
    "is_valid_cuspEmax",
    "tp_trapTmax",
    "cuspEmax_ctc_cal"
]
#channels_list = channels_rawid[detector_type]

# --------------------------
# PRE-CACHING (fuori loop)
# --------------------------
start_key = meta.dataprod.runinfo.p03.r001.cal.start_key
dsp_overrides_all = meta.dataprod.overrides.dsp.on(start_key)

forced_trigger_np = ak.to_numpy(trigger_data["is_forced"])
channels_list = channels_tot
with PdfPages(output_pdf) as pdf:
    for i, channel in tqdm(enumerate(channels_list)):
        print(f"\n==================================== {channel} {i+1}/{len(channels_list)} ====================================\n")
    
        # --------------------------
        # CALIBRAZIONE
        # --------------------------
        cal_dict = Props.read_from(cal_file)[channel]["pars"]["operations"]
    
        # --------------------------
        # LOAD DATA (NO COPY)
        # --------------------------
        data = load_data(
            files=psp_file,
            lh5_path=f"{channel}/dsp",
            cal_dict=cal_dict,
            params=params,
            return_selection_mask=False,
        )
    
        # --------------------------
        # FLAGS GLOBALI
        # --------------------------
        data["forced_trigger"] = forced_trigger_np
        data["is_pulser"] = coincident_data["puls"]
        data["is_muon"] = coincident_data["muon_offline"]
        data["is_HPGe"] = coincident_data["geds"]
    
        data["is_discharge"] = geds_data.quality.is_not_bb_like.is_delayed_discharge
    
        data["is_below_100keV"] = (
            (data["cuspEmax_ctc_cal"] > 0) &
            (data["cuspEmax_ctc_cal"] < 40)
        )
    
        # --------------------------
        # CACHE LOCALI (IMPORTANTE)
        # --------------------------
        is_hpge = data["is_HPGe"]
        is_muon = data["is_muon"]
        is_pulser = data["is_pulser"]
        forced_trigger = data["forced_trigger"]
        is_discharge = data["is_discharge"]
        is_below_100keV = data["is_below_100keV"]
        bl_slope = data["is_valid_bl_slope"]
        bl_slope_rms_class = data["is_valid_bl_slope_rms"]
        tail_rms_class = data["is_valid_tail_rms"]
        noise_burst = data["is_not_noise_burst"]
        cuspEmin = data["is_valid_cuspEmin"]
        cuspEmax = data["is_valid_cuspEmax"]
    
        # --------------------------
        # MASCHERE
        # --------------------------
        m_fix = is_hpge & ~is_muon
        m_discharge = ~is_discharge
        m_qc = bl_slope & bl_slope_rms_class & tail_rms_class & noise_burst & cuspEmin & ~cuspEmax

        m_failed_trapTmax = (data["tp_trapTmax"] > 55000 ) & ( data["tp_trapTmax"] < 65000)
    
        # --------------------------
        # SELEZIONE
        # --------------------------
        low_energy_selection = (
            m_discharge &
            ~is_pulser &
            ~forced_trigger &
            m_fix &
            is_below_100keV &
            m_qc &
            m_failed_trapTmax
        )
    
        n_selected = int(np.sum(low_energy_selection))
        print(n_selected, "Low energy events")
    
        if n_selected == 0:
            print("No events → skipping channel")
            continue
    
        # --------------------------
        # OVERRIDES DSP
        # --------------------------
        dsp_overrides = dsp_overrides_all[channel]
    
        # --------------------------
        # BROWSER
        # --------------------------
        # colormap fredda
        cmap = plt.cm.Blues  # alternativa: plt.cm.Greys, plt.cm.cividis
        
        n = n_selected
        colors = cmap(np.linspace(0.3, 0.95, n))
        browser = WaveformBrowser(
            raw_file,
            f"{channel}/raw",
            dsp_config=dsp_config,
            database=dsp_overrides,
            lines=[#"wf_blsub",
                    "wf_pz",],
                    #"wf_trap",],
                    #"cuspEmax",],
            aux_values=data,
            legend=["E = {cuspEmax_ctc_cal} keV"],
            legend_opts={"loc": "lower right"},
            entry_mask=low_energy_selection,
            n_drawn=n_selected,
            styles={"color": colors}
            
        )
    
        browser.draw_next()
        plt.title(f"chn : {channel}")
        plt.ylabel("Signal (ADC)")
        plt.xlabel("Time (ns)")
        plt.grid(alpha=0.25, ls="--")
    
        fig = plt.gcf()   # prende la figura corrente

        pdf.savefig(fig)
        plt.close(fig)

print("=======================  finished ===========================")
